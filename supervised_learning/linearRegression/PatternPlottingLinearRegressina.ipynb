# %%
import random
import numpy as np
import matplotlib.pyplot  as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
X=np.random.rand(50,1)
Y =1.3*(X**8)-1.4*(X**7)-0.5*(X**6)+0.4*(X**5)-0.3*(X**4)+0.05*(X**3)+1.2*(X**2)-0.6*X+ 0.1*np.random.rand(50,1)

fig = plt.figure()
plt.scatter(X,Y)

plt.show()

# %%
for i in range(1,5):
    print(f"serial No.",i)
    poly = PolynomialFeatures(i)
    x_poly = poly.fit_transform(X)
    scaler = StandardScaler()
    scaler.fit(x_poly)
    x_poly_stnd = scaler.transform(x_poly)
    model=LinearRegression()
    model.fit(x_poly_stnd, Y)
    
    output = model.predict(x_poly_stnd)
    
    
    #plotting the graph
    
    fig = plt.figure()
    plt.plot(X[sort_idx, 0], output[sort_idx, 0], color='red', label='predict')
    plt.scatter(X,Y,label="given")
    plt.show()
# Out:
# serial No. 1
# serial No. 2
# serial No. 3
# serial No. 4
